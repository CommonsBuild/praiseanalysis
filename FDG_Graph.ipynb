# %%
import pandas as pd
import hvplot.pandas

# %%
df = pd.read_csv('sample_praise_set.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'To', 'From', 'Reason for dishing', 'Server', 'Date',
#        'Room', 'v1 norm', 'v2 norm', 'v3 norm', 'Avg %', 'IH per Praise',
#        'IH per person', 'Unnamed: 12', 'v1', 'v2', 'v3', 'period',
#        'Cred per Praise', 'Cred per person', 'To.1', 'Room-NoEmoji', 'Source',
#        'Year', 'Month', 'Day'],
#       dtype='object')

# %% [markdown]
# Isolate a simple dataset with just to from and how much.

# %%
df
# Out:
#      Unnamed: 0              To            From  \
# 0          6077         liviade      cranders71
# 1           421    chuygarcia92         Tam2140
# 2            70       iviangita       iviangita
# 3          7141     ygganderson  JessicaZartler
# 4          5293       metaverde       iviangita
# ..          ...             ...             ...
# 495        6915      GriffGreen         liviade
# 496        7149     ygganderson         liviade
# 497        2270         Tam2140       iviangita
# 498        2514  JessicaZartler       iviangita
# 499        5115          vegayp       iviangita
#
#                                     Reason for dishing  \
# 0    always caring for our finicky bot and valued c...
# 1    for the Masana Temples recommendation. Nice mi...
# 2                   for joining the Legal weekly sync
# 3    their presence, energy and smiles in the Comms...
# 4    mentioning or retweeting TE Commons on the soc...
# ...

# %%
df = df[['To','From', 'IH per Praise']]

# %% [markdown]
# Fill nan values with the mean.

# %%
df['IH per Praise'] = df['IH per Praise'].fillna(df['IH per Praise'].mean())

# %%
weighted_edges = df.groupby(['To','From']).sum().reset_index()

# %%
df.groupby('To')['IH per Praise'].sum().sort_values(ascending=False).hvplot.hist(bins=60, title='Total IH Received')
# Out:
# :Histogram   [IH per Praise]   (IH per Praise_count)

# %%
df.groupby('From')['IH per Praise'].sum().sort_values(ascending=False).hvplot.hist(bins=60, title='Total IH Given')
# Out:
# :Histogram   [IH per Praise]   (IH per Praise_count)

# %%
df.pivot_table(index='From',columns='To',values='IH per Praise',aggfunc=sum)
# Out:
# To               AdaptDAO  AnnaMarieSwan#8824  BadJuju#1050    BlairV  \
# From
# GriffGreen            NaN                 NaN           NaN  2.962303
# JessicaZartler        NaN                 NaN           NaN  2.471925
# JuankBell             NaN                 NaN           NaN       NaN
# Krisjones             NaN                 NaN      1.135215       NaN
# Laurenluz             NaN                 NaN           NaN       NaN
# Mettodo#7010          NaN                 NaN           NaN       NaN
# PKK777                NaN                 NaN           NaN       NaN
# Santigs67             NaN                 NaN           NaN       NaN
# Sponnet2              NaN                 NaN           NaN       NaN
# Suga#8514             NaN                 NaN           NaN       NaN
# Tam2140               NaN                 NaN           NaN       NaN
# Tonga2020             NaN                 NaN           NaN       NaN
# ...

# %% [markdown]
# Making the nodes.

# %%
nodes = set(df['To']).union(set(df['From']))
nodes = [{"id": i, "group": 1} for i in nodes]
nodes

# %% [markdown]
# Making the edges.

# %%
weighted_edges.columns = ['target', 'source', 'value']

edges = weighted_edges.to_dict(orient='records')

# %% [markdown]
# Generating the data as json.

# %%
data = {
    'nodes': nodes,
    'links': edges,
}

import json
with open('fdg/data.json', 'w') as fp:
    json.dump(data, fp)

# %% [markdown]
# To visualize the network, go into ./fdg and run: `python3 -m http.server`
