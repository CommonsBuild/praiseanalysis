# %% [markdown]
# # Language Embedding
#
# We can use doc2vec to make a spatial embedding of the reasons for dishing.

# %% [markdown]
# https://radimrehurek.com/gensim/models/doc2vec.html
# https://medium.com/@mishra.thedeepak/doc2vec-simple-implementation-example-df2afbbfbad5
# https://towardsdatascience.com/multi-class-text-classification-with-doc2vec-logistic-regression-9da9947b43f4
# https://www.analyticsvidhya.com/blog/2020/08/top-4-sentence-embedding-techniques-using-python/

# %%
import pandas as pd

df = pd.read_csv('cleaned-non-quantifier-data.csv')

df
# Out:
#                            To            From  \
# 0                   zeptimusQ         Tam2140
# 1                   zeptimusQ       iviangita
# 2                   zeptimusQ       JuankBell
# 3                   zeptimusQ       iviangita
# 4                   zeptimusQ       iviangita
# ...                       ...             ...
# 7620                   atacas         liviade
# 7621                Luukweber       iviangita
# 7622                  krrisis      GriffGreen
# 7623                  sbilbao  JessicaZartler
# 7624  CryptononymousEconomist  JessicaZartler
#
#                                      Reason for dishing  \
# 0               for hosting this kicking params party!
# 1      for hosting and leading a lot of params parties
# 2     for testing and deploying the bot to record an...
# 3              for the huge success of the MVV process
# 4     for his awesome work on the recorder bot, for ...
# ...                                                 ...
# 7620  their presence and great contributions to the ...
# 7621           participating in the Praisegiving Call 😀
# 7622  sharing the gitcoin blog post... lots of great...
# 7623  joining the TE Praise channel and the TEC lab ...
# 7624  joining the TE Praise channel and the TEC lab ...
#
#                          Server        Date           Room  v1 norm  v2 norm  \
# 0     Token Engineering Commons  2021-05-07        🙏praise  10000.0    100.0
# 1     Token Engineering Commons  2021-05-07        🙏praise  10000.0    100.0
# 2     Token Engineering Commons  2021-04-28        🙏praise   1000.0    200.0
# 3     Token Engineering Commons  2021-04-30        🙏praise   1000.0    200.0
# 4     Token Engineering Commons  2021-04-30        🙏praise   1000.0    200.0
# ...                         ...         ...            ...      ...      ...
# 7620                   Telegram  2020-12-01      TE Praise     30.0     60.0
# 7621                   Telegram  2020-11-28      TE Praise     40.0     30.0
# 7622                   Telegram  2020-12-02  Commons Stack     10.0     40.0
# 7623                   Telegram  2020-11-27      TE Praise     50.0     30.0
# 7624                   Telegram  2020-11-27      TE Praise     50.0     30.0
#
#       v3 norm     Avg %  ...     v3     period Cred per Praise  \
# 0       200.0  0.001963  ...    Edu  #17 May 7             NaN
# 1       100.0  0.001663  ...    Edu  #17 May 7             NaN
# 2       200.0  0.001342  ...    Edu  #17 May 7             NaN
# 3       100.0  0.001043  ...    Edu  #17 May 7             NaN
# 4       100.0  0.001043  ...    Edu  #17 May 7             NaN
# ...       ...       ...  ...    ...        ...             ...
# 7620     40.0  0.001534  ...  Santi   #6 Dec 4        1.201248
# 7621     30.0  0.001180  ...  Santi   #6 Dec 4        0.924158
# 7622     40.0  0.001103  ...  Santi   #6 Dec 4        0.863962
# 7623     10.0  0.001005  ...  Santi   #6 Dec 4        0.786973
# 7624     10.0  0.001005  ...  Santi   #6 Dec 4        0.786973
#
#      Cred per person To.1   Room-NoEmoji                            Source  \
# 0                NaN  NaN         praise  Token Engineering Commons:praise
# 1                NaN  NaN         praise  Token Engineering Commons:praise
# 2                NaN  NaN         praise  Token Engineering Commons:praise
# 3                NaN  NaN         praise  Token Engineering Commons:praise
# 4                NaN  NaN         praise  Token Engineering Commons:praise
# ...              ...  ...            ...                               ...
# 7620        0.969588  NaN      TE Praise                Telegram:TE Praise
# 7621        0.924158  NaN      TE Praise                Telegram:TE Praise
# 7622        0.863962  NaN  Commons Stack            Telegram:Commons Stack
# 7623        0.786973  NaN      TE Praise                Telegram:TE Praise
# 7624        0.786973  NaN      TE Praise                Telegram:TE Praise
#
#       Year  Month  Day
# 0     2021      5    7
# 1     2021      5    7
# 2     2021      4   28
# 3     2021      4   30
# 4     2021      4   30
# ...    ...    ...  ...
# 7620  2020     12    1
# 7621  2020     11   28
# 7622  2020     12    2
# 7623  2020     11   27
# 7624  2020     11   27
#
# [7625 rows x 25 columns]

# %%
# !pip install gensim
# !pip install nltk
# import nltk
# nltk.download('punkt')
#Import all the dependencies
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
data = ["I love machine learning. Its awesome.",
        "I love coding in python",
        "I love building chatbots",
        "they chat amagingly well"]

tagged_data = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in enumerate(data)]

# %%
max_epochs = 100
vec_size = 20
alpha = 0.025

# %%
import gensim

# %%
gensim.__version__
# Out:
# '4.0.1'

# %%
model = Doc2Vec(size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-47fe62f650a9> in <module>
# ----> 1 model = Doc2Vec(size=vec_size,
#       2                 alpha=alpha,
#       3                 min_alpha=0.00025,
#       4                 min_count=1,
#       5                 dm =1)
#
# ~/.virtualenvs/TEC/lib/python3.8/site-packages/gensim/models/doc2vec.py in __init__(self, documents, corpus_file, vector_size, dm_mean, dm, dbow_words, dm_concat, dm_tag_count, dv, dv_mapfile, comment, trim_rule, callbacks, window, epochs, **kwargs)
#     285         self.dv.vectors_lockf = np.ones(1, dtype=REAL)  # 0.0 values suppress word-backprop-updates; 1.0 allows
#     286
# --> 287         super(Doc2Vec, self).__init__(
#     288             sentences=corpus_iterable,
#     289             corpus_file=corpus_file,
#
# TypeError: __init__() got an unexpected keyword argument 'size'

# %%
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha
