# %% [markdown]
# ### Import essential libraries

# %%
import pandas as pd
import texthero as hero # for effective dataframe cleaning 
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize 
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\fmagh\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# ### Read and clean main data

# %%
# reading praise data
df_praise = pd.read_csv("data/cleaned-non-quantifier-data.csv", index_col=False)

# convert date column from object to datetime format
df_praise["Date"] =  pd.to_datetime(df_praise["Date"], format='%Y-%m-%d')

# droppping unnecessary columns
df_praise.drop(["Year", "Month", "Day"], axis=1, inplace=True)

df_praise[(df_praise['IH per Praise'] -  48.829077) < 1]

df_praise.head(4)
# Out:
#           To       From                                 Reason for dishing  \
# 0  zeptimusQ    Tam2140            for hosting this kicking params party!
# 1  zeptimusQ  iviangita   for hosting and leading a lot of params parties
# 2  zeptimusQ  JuankBell  for testing and deploying the bot to record an...
# 3  zeptimusQ  iviangita           for the huge success of the MVV process
#
#                       Server       Date     Room  v1 norm  v2 norm  v3 norm  \
# 0  Token Engineering Commons 2021-05-07  🙏praise  10000.0    100.0    200.0
# 1  Token Engineering Commons 2021-05-07  🙏praise  10000.0    100.0    100.0
# 2  Token Engineering Commons 2021-04-28  🙏praise   1000.0    200.0    200.0
# 3  Token Engineering Commons 2021-04-30  🙏praise   1000.0    200.0    100.0
#
#       Avg %  IH per Praise  IH per person Unnamed: 12         v1     v2   v3  \
# 0  0.001963       2.355252       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 1  0.001663       1.995539       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 2  0.001342       1.610872       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 3  0.001043       1.251160       39.04072   zeptimusQ  Metaverde  Juank  Edu
#
#       period  Cred per Praise  Cred per person  To.1 Room-NoEmoji  \
# 0  #17 May 7              NaN              NaN   NaN       praise
# 1  #17 May 7              NaN              NaN   NaN       praise
# 2  #17 May 7              NaN              NaN   NaN       praise
# 3  #17 May 7              NaN              NaN   NaN       praise
#
#                              Source
# 0  Token Engineering Commons:praise
# 1  Token Engineering Commons:praise
# 2  Token Engineering Commons:praise
# 3  Token Engineering Commons:praise

# %% [markdown]
# ### Read and clean tag data

# %%
# reading tag data
df_tag = pd.read_csv("data/Praise_quantifier_tags.csv", index_col=False)

# concatenating keywords and category columns to have a one comprehensive key column
df_tag["keyword"] = df_tag["Category"].str.cat(df_tag["Keywords"], sep=", ")
df_tag["keyword"].fillna(df_tag['Category'], inplace=True)
df_tag = df_tag.iloc[:16, [0,6]]
df_tag.columns = ["tag", "keyword"]

# some cleaning
df_tag["keyword"] = hero.clean(df_tag["keyword"])
df_tag
# Out:
# C:\Users\fmagh\anaconda3\lib\site-packages\texthero\preprocessing.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   return input.str.replace(r"^\d+\s|\s\d+\s|\s\d+$", " ")
# C:\Users\fmagh\anaconda3\lib\site-packages\texthero\preprocessing.py:81: FutureWarning: The default value of regex will change from True to False in a future version.
#   return input.str.replace(pat, '')
#       tag                                            keyword
# 0    TEC1  comms article blog organized presentation grap...
# 1    TEC2  culture build soft gov soft gov survey vote vo...
# 2    TEC3       params parameters params param param parties
# 3    TEC4                   legal legal legal legal strategy
# 4    TEC5  commons swarm tech dev dapp app tech dev dapp ...
# 5    TEC6  hatch outreach onboarding onboarding hatch out...
# 6    TEC7                            omega survey philosophy
# 7    TEC8         stewards github steward project management
# 8    TEC9                                               labs
# 9   TEC10  transparency transparency youtube recording tr...
# 10  TEC12                             participation retweets
# 11  TEC13                   fundraising donating fundraising
# 12  TEC14                           technical infrastructure
# 13  TEC15                             tec community building
# 14  TEC16                                    personal praise
# 15  TEC17  gravity gravity conflict non violent communica...

# %% [markdown]
# ### Building `Doc2Vec` model and traing it

# %%
# list of keyword data
data = list(df_tag.keyword)

# building tagged data with respect to name of tags
tagged_data = [TaggedDocument(words=word_tokenize(d.lower()), tags=[str(i)]) for  d, i in zip(data, df_tag["tag"])]

# initializing some variables
max_epochs = 100
vec_size = 20
alpha = 0.025
# building model
model = Doc2Vec(vector_size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)

model.build_vocab(tagged_data)

# training model with respect to max_epochs as a number of iteration
for epoch in range(max_epochs):
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=60)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha
    
# save model, then later we can load and add to it
# without need to train it from scratch
model.save("data/cache/tag_d2v.model")

# model= Doc2Vec.load("data/cache/d2v.model")

# %% [markdown]
# ### Testing model

# %%
# to find the vector of a document which is not in training data
test_data = word_tokenize("recording".lower())
v1 = model.infer_vector(test_data)

# to find most similar doc using tags
model.dv.most_similar([v1])
# Out:
# [('TEC10', 0.8960395455360413),
#  ('TEC13', 0.6778905987739563),
#  ('TEC12', 0.6620689630508423),
#  ('TEC8', 0.6302334070205688),
#  ('TEC15', 0.6228792071342468),
#  ('TEC16', 0.6140098571777344),
#  ('TEC4', 0.6041674613952637),
#  ('TEC17', 0.60159832239151),
#  ('TEC2', 0.5972786545753479),
#  ('TEC14', 0.5870808362960815)]

# %% [markdown]
# ### Adding tag column to praise data and save it

# %%
# adding tag to data
tag_list = []

for index_, row in df_praise.iterrows():
    tag_doc = word_tokenize(row[2].lower())
    tag_doc_vector = model.infer_vector(tag_doc)
    tag_list.append(model.dv.most_similar([tag_doc_vector])[0][0])
    
df_praise["tags"] = tag_list
df_praise.to_csv("data/tagged_praise_data.csv")

# %%
df_praise.head(10)
# Out:
#           To        From                                 Reason for dishing  \
# 0  zeptimusQ     Tam2140            for hosting this kicking params party!
# 1  zeptimusQ   iviangita   for hosting and leading a lot of params parties
# 2  zeptimusQ   JuankBell  for testing and deploying the bot to record an...
# 3  zeptimusQ   iviangita           for the huge success of the MVV process
# 4  zeptimusQ   iviangita  for his awesome work on the recorder bot, for ...
# 5  zeptimusQ     Tam2140  for taking care of Ivy's access to Twitter DMs!!
# 6  zeptimusQ  GriffGreen  and the many other community members that did ...
# 7  zeptimusQ     Tam2140  for keeping the Stewards, and all Working Grou...
# 8  zeptimusQ   iviangita                        for all the awesome MEMES!
# 9  zeptimusQ  cranders71  for attending the 1Hive TEC Hatch Params Party...
#
#                       Server       Date      Room  v1 norm  v2 norm  v3 norm  \
# 0  Token Engineering Commons 2021-05-07   🙏praise  10000.0    100.0    200.0
# 1  Token Engineering Commons 2021-05-07   🙏praise  10000.0    100.0    100.0
# 2  Token Engineering Commons 2021-04-28   🙏praise   1000.0    200.0    200.0
# 3  Token Engineering Commons 2021-04-30   🙏praise   1000.0    200.0    100.0
# 4  Token Engineering Commons 2021-04-30   🙏praise   1000.0    200.0    100.0
# 5  Token Engineering Commons 2021-04-30   🙏praise   1000.0    100.0    200.0
# 6  Token Engineering Commons 2021-05-03  🎫general   1000.0    100.0    200.0
# 7  Token Engineering Commons 2021-05-06   🙏praise   1000.0    100.0    200.0
# 8  Token Engineering Commons 2021-05-07   🙏praise   1000.0    100.0    200.0
# 9  Token Engineering Commons 2021-05-07   🙏praise   1000.0    100.0    200.0
#
#       Avg %  IH per Praise  IH per person Unnamed: 12         v1     v2   v3  \
# 0  0.001963       2.355252       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 1  0.001663       1.995539       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 2  0.001342       1.610872       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 3  0.001043       1.251160       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 4  0.001043       1.251160       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 5  0.001023       1.227785       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 6  0.001023       1.227785       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 7  0.001023       1.227785       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 8  0.001023       1.227785       39.04072   zeptimusQ  Metaverde  Juank  Edu
# 9  0.001023       1.227785       39.04072   zeptimusQ  Metaverde  Juank  Edu
#
#       period  Cred per Praise  Cred per person  To.1 Room-NoEmoji  \
# 0  #17 May 7              NaN              NaN   NaN       praise
# 1  #17 May 7              NaN              NaN   NaN       praise
# 2  #17 May 7              NaN              NaN   NaN       praise
# 3  #17 May 7              NaN              NaN   NaN       praise
# 4  #17 May 7              NaN              NaN   NaN       praise
# 5  #17 May 7              NaN              NaN   NaN       praise
# 6  #17 May 7              NaN              NaN   NaN      general
# 7  #17 May 7              NaN              NaN   NaN       praise
# 8  #17 May 7              NaN              NaN   NaN       praise
# 9  #17 May 7              NaN              NaN   NaN       praise
#
#                               Source   tags
# 0   Token Engineering Commons:praise   TEC3
# 1   Token Engineering Commons:praise   TEC3
# 2   Token Engineering Commons:praise   TEC7
# 3   Token Engineering Commons:praise   TEC6
# 4   Token Engineering Commons:praise  TEC10
# 5   Token Engineering Commons:praise   TEC9
# 6  Token Engineering Commons:general  TEC15
# 7   Token Engineering Commons:praise   TEC8
# 8   Token Engineering Commons:praise   TEC1
# 9   Token Engineering Commons:praise  TEC16
