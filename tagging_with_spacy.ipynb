# %% [markdown]
# ### Import essential libraries

# %%
import pandas as pd
import numpy as np
import texthero as hero # cleaning pandas columns
import time
import nltk
import spacy # check similarity of words precisely
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ### Read `praise` and `tag` data into pandas dataframe and perform some cleansing

# %%
df_praise = pd.read_csv("data/sample_praise.csv")
df_tag = pd.read_csv("data/tags.csv")

df_praise.iloc[:,5] = hero.clean(df_praise.iloc[:,5])
df_praise = pd.concat([df_praise.iloc[:,0], df_praise.iloc[:,3:15]], axis=1)
# Out:
# C:\Users\fmagh\anaconda3\lib\site-packages\texthero\preprocessing.py:46: FutureWarning: The default value of regex will change from True to False in a future version.
#   return input.str.replace(r"^\d+\s|\s\d+\s|\s\d+$", " ")
# C:\Users\fmagh\anaconda3\lib\site-packages\texthero\preprocessing.py:81: FutureWarning: The default value of regex will change from True to False in a future version.
#   return input.str.replace(pat, '')

# %%
df_praise.head(5)
# Out:
#   Category Code            To            From  \
# 0         TEC15       liviade      cranders71
# 1         TEC12  chuygarcia92         Tam2140
# 2         TEC12     iviangita       iviangita
# 3         TEC12   ygganderson  JessicaZartler
# 4         TEC12     metaverde       iviangita
#
#                                                                                                                Reason for dishing  \
# 0                                                                              always caring finicky bot valued community members
# 1                                                                           masana temples recommendation nice mix low high beats
# 2                                                                                                       joining legal weekly sync
# 3                                                                                presence energy smiles comms working group today
# 4  mentioning retweeting te commons socials past week thank helping us grow token engineering commons community spreading message
#
#                       Server        Date        Room v1 norm  v2 norm  \
# 0                   Telegram  2021-01-13   TE Praise      30     10.0
# 1  Token Engineering Commons  2021-04-30     🙏praise    1000    100.0
# 2  Token Engineering Commons  2021-04-30     🙏praise    1000     80.0
# 3                   Telegram  2020-11-24   TE Praise      20     60.0
# 4                   Telegram  2021-01-22  TE Commons     NaN      NaN
#
#    v3 norm          Avg %        IH per Praise  IH per person
# 0     40.0  6.549.137.185        4.911.852.889  6.767.403.323
# 1    100.0    723.394.157        8.680.729.884    718.127.319
# 2    100.0  6.595.463.701        7.914.556.442  2.387.003.435
# 3     30.0  1.283.215.058                  NaN            NaN
# 4      NaN              0  198.159.943.382.873  3.170.559.094

# %%
df_tag
# Out:
#       tag  \
# 0    TEC1
# 1    TEC2
# 2    TEC3
# 3    TEC4
# 4    TEC5
# 5    TEC6
# 6    TEC7
# 7    TEC8
# 8    TEC9
# 9   TEC10
# 10  TEC12
# 11  TEC13
# 12  TEC14
# 13  TEC15
# 14  TEC16
# 15  TEC17
#
#                                                                                                                                                                                                                               keyword
# 0   comms article blog organized presentation graphic design website marketing seo social platform discord telegram forum discourse medium linkedin website article retweeting retweet retweets organized presentation communications
# 1                                                                                                                                                                                    culture build soft gov survey vote voting debate
# 2                                                                                                                                                                                               params parameters param parties party
# 3                                                                                                                                                                                                                      legal strategy
# 4                                                                                                                                                                                       commons swarm tech dev dapp tech dapp app bug
# 5                                                                                                                                                                                          hatch outreach onboarding onboard outreach
# 6                                                                                                                                                                                                             omega survey philosophy
# 7                                                                                                                                                                                          stewards github steward project management
# 8                                                                                                                                                                                                                            labs lab
# 9                                                                                                                                                                                               transparency youtube recording record
# 10                                                                                                                                                                                                             participation retweets
# 11                                                                                                                                                                                                   fundraising donating fundraising
# 12                                                                                                                                                                                                           technical infrastructure
# 13                                                                                                                                                                                                             tec community building
# 14                                                                                                                                                                                                                    personal praise
# 15                                                                                                                                                                                          gravity conflict nonviolent communication

# %% [markdown]
# ### `check_freq` function returns most frequent tag for each row

# %%
def check_freq(tag_list):
    final_tag_list = []
    try:
        for lst in tag_list:
            str_ = ''
            for item in tag_list:
                str_ = str_ +" "+ item
            moby_tokens = nltk.word_tokenize(str_)
            text = nltk.Text(moby_tokens)

            dist = nltk.FreqDist(text)
            freq_lst = [k for k, v in sorted(dist.items(), key=lambda i: i[1], reverse=True)]
            final_tag_list.append(freq_lst[0])
        return final_tag_list[0]
    except:
        return []

# %% [markdown]
# ### Iterating through all rows and tag data just for equal words(100% similarity based on tag dataset)

# %%
tag_dict = set()
for index_, row in df_tag.iterrows():
    tag_dict.add((row[0], row[1]))
    
tag_dict
# Out:
# {('TEC1',
#   'comms article blog organized presentation graphic design website marketing seo social platform discord telegram forum discourse medium linkedin website article retweeting retweet retweets organized presentation communications'),
#  ('TEC10', 'transparency youtube recording record'),
#  ('TEC12', 'participation retweets'),
#  ('TEC13', 'fundraising donating fundraising'),
#  ('TEC14', 'technical infrastructure'),
#  ('TEC15', 'tec community building'),
#  ('TEC16', 'personal praise'),
#  ('TEC17', 'gravity conflict nonviolent communication'),
#  ('TEC2', 'culture build soft gov survey vote voting debate'),
#  ('TEC3', 'params parameters param parties party'),
#  ('TEC4', 'legal strategy'),
#  ('TEC5', 'commons swarm tech dev dapp tech dapp app bug'),
#  ('TEC6', 'hatch outreach onboarding onboard outreach'),
#  ('TEC7', 'omega survey philosophy'),
#  ('TEC8', 'stewards github steward project management'),
#  ('TEC9', 'labs lab')}

# %%
praise_set = set()
for index_, row in df_praise.iloc[:100,:].iterrows():
    praise_set.add((index_, row[3]))
    
praise_set
# Out:
# {(0, 'always caring finicky bot valued community members'),
#  (1, 'masana temples recommendation nice mix low high beats'),
#  (2, 'joining legal weekly sync'),
#  (3, 'presence energy smiles comms working group today'),
#  (4,
#   'mentioning retweeting te commons socials past week thank helping us grow token engineering commons community spreading message'),
#  (5,
#   'engaging discussion te commons forum https forum tecommons org past week thank helping token engineering commons community share learn'),
#  (6,
#   'mentioning retweeting te commons socials past week thank helping us grow token engineering commons community spreading message'),
#  (7, 'insightful well formed presentation gravity today'),
#  (8, 'conducting giving feedback audit'),
#  (9, 'last session gravity incredible whole ecosystem'),
#  (10,
#   'joining hack session staying great discussion anarchy vs community governance'),
#  (11, 'bringing board zenhub team'),
#  (12, 'joining tec community call https www youtube com watch v dhnrqaow3ic'),
#  (13, 'drafting audit proposal amazing'),
#  (14, 'great energy thought provoking conversation legal wg weekly sync'),
#  (15,
#   'amazing collaborations interest gravity project take care helping set strong basements high quality standards application alternative dispute resolution daos ethical professional responsibility'),
#  (16, 'hours meeting gardens prep weekly recap'),
#  (17,
#   'always available help work gravity living life graviton inspiring everyone incredible work gravity work gravity working around eth colombia community always really cool encouraging'),
#  (18, 'awesome work gitbook contributions giving even new'),
#  (19, 'griffgreen guiding scholarship request'),
#  (20, 'joining book club last week'),
#  (21,
#   'mentioning retweeting commons stack socials past week thank helping us grow commons stack community spreading message'),
#  (22, 'awesome people interacted juan recently conversations amazing'),
#  (23, 'test'),
#  (24,
#   'delightful blogpost https medium com token engineering commons economy choice v2 4f7c9fb42d99'),
#  (25, 'great conversations dan helping trusted seed'),
#  (26,
#   'mentioning us retweeting us socials december thank helping us growing commons stack community spreading message'),
#  (27, 'productive efficient onboarding wg weekly sync'),
#  (28, 'dropping comms call'),
#  (29, 'contributing much community'),
#  (30, 'warm welcome gave tam'),
#  (31, 'zeptimus gabi joining commons swarm weekly sync'),
#  (32,
#   'willszal 6405 mentioning retweeting commons stack socials past week thank helping us grow commons stack community spreading message'),
#  (33, 'joining stewards call'),
#  (34, 'joining legal weekly sync'),
#  (35, 'joining commons stack simulator sync continuing improve game'),
#  (36, 'joining community stewards sync yesterday'),
#  (37, 'great work part commons simulator deep dive'),
#  (38, 'attending today impact hours deep dive looking forward parameter sets'),
#  (39,
#   'donating commons simulator grant btw watch email week special invite first play game completely done'),
#  (40,
#   "joining legal wg discuss meeting attendance terms idea audit ' amazing put practice incredible work ' transparency going beyond scope"),
#  (41, 'great input todays gravity call'),
#  (42, 'reviewing dapp critical legal eye'),
#  (43,
#   'mentioning retweeting commons stack socials past week thank helping us grow commons stack community spreading message'),
#  (44, 'helping suga taking block'),
#  (45, 'joining community stewards sync yesterday'),
#  (46, 'visible community work hatch super cool'),
#  (47, 'starting lively dialogue around governance'),
#  (48, 'contributing latest tec praise quant blog'),
#  (49,
#   'creating praise system huge pillar gratitude culture implementing tec via contribution reward proposal early days cultural build lucky human based approach rewards going beyond concrete contributions also acknowledging subjective care work ones'),
#  (50, 'helping push gitcoin things comms'),
#  (51, 'tackling remaining issues swiss membership dapp'),
#  (52,
#   'sharing decentralized learning journey much honesty humor open contributions graviton training'),
#  (53, 'overall presence stability mind work gravity'),
#  (54,
#   'coming recording gardens swarm call every time writing transparency wg forum post https forum tecommons org transparency working group 197'),
#  (55,
#   'annamarieswan freedumbs00 natesuits juankbell mateodaza griff santigs suga zeptimus amwfund durgadas tam2140 chuygarcia92 joining soft gov always insightful spend time'),
#  (56, 'joining tec weekly sync'),
#  (57,
#   'joining commons stack simulator sync continuing push project finish line'),
#  (58,
#   'willszal 6405 mentioning retweeting commons stack socials past week thank helping us grow commons stack community spreading message'),
#  (59, 'joining book club last week'),
#  (60, 'starting cadcad bootcamp study group'),
#  (61, 'joining tec weekly sync'),
#  (62,
#   'giving great talk ethdenver representing tec ethdenver onboarding lot people wednesday call participatory jake onboarding still focused ethdenver hosting ama call'),
#  (63, 'joining call helping onboarding auryn'),
#  (64, 'reaching help trusted seed membership dues going'),
#  (65, 'understanding intentions moving space'),
#  (66,
#   'mission vision value tokenlog waterfall griff land america sprint planning session'),
#  (67, 'joining mission token log hack session'),
#  (68, 'getting us hatch handling applications hatchers'),
#  (69, 'fascinating informational deep dive dandelion voting parameters'),
#  (70, 'presence great contributions soft gov wg sync'),
#  (71,
#   'mentioning retweeting te commons socials past week thank helping us grow token engineering commons community spreading message'),
#  (72, 'work decentralizing data markets'),
#  (73,
#   'joining commons stack simulator sync continuing push project finish line'),
#  (74, 'amazing panel daos yesterday livia'),
#  (75,
#   'donating commons stack iteration gitcoin grant helping us raise 14 000 dai build future high functioning public goods focused economies'),
#  (76, 'work gravity'),
#  (77, 'coming soft gov call last week sorry late praise'),
#  (78,
#   'mentioning retweeting commons stack socials past week thank helping us grow commons stack community spreading message'),
#  (79, 'great work organizing gitbook'),
#  (80, 'dank memes meme party'),
#  (81, 'working hatch backend'),
#  (82,
#   'mentioning retweeting commons stack socials past week thank helping us grow commons stack community spreading message'),
#  (83, 'lot communication juan strengthens trust relationship'),
#  (84, 'rallying around last push get hash contracts frozen'),
#  (85, 'great new landing page'),
#  (86, 'cs dev diagrams'),
#  (87, 'awesome article automating ostrom effective dao management'),
#  (88,
#   'work tec test hatch dao spec https forum tecommons org tec test hatch implementation specification 226'),
#  (89, 'donating commons stack community fund panvala league grant'),
#  (90, 'lot work see'),
#  (91, 'joining tec weekly sync'),
#  (92,
#   'starting getting stuck reverse engineering unravelling compound finance'),
#  (93, 'test'),
#  (94, 'joining tec community call https www youtube com watch v s8rqw7bf8gk'),
#  (95,
#   'donating commons stack iteration gitcoin grant helping us raise 14 000 dai build future high functioning public goods focused economies'),
#  (96, 'continuing hard work params offering support comms well rock'),
#  (97, 'putting heads finding bug'),
#  (98, 'joining tec weekly sync https www youtube com watch v efhuvu oc0'),
#  (99, 'showing forum posts contributing')}

# %%
list_tag = []
temp_1 = []
counter = 0

start_time = time.time()
for index_praise in praise_set:
    temp_1 = [row_tag[0] for row_tag in tag_dict for item_praise in set(index_praise[1].split(" ")) for item_tag in set(row_tag[1].split(" ")) if nlp(item_praise).similarity(nlp(item_tag)) == 1]
    if len(temp_1)>=1:
        list_tag.append((index_praise[0], check_freq(temp_1)))
        temp_1 = []
    else:
        list_tag.append((index_praise[0],np.nan))
    print(f"row {counter} is done.", end='\r')
    counter+=1

end_time = time.time()
print(f"\nTotal run time for {len(praise_set)} rows is: {end_time - start_time}")
# Out:
# <ipython-input-70-f92e2e360ea9>:7: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   temp_1 = [row_tag[0] for row_tag in tag_dict for item_praise in set(index_praise[1].split(" ")) for item_tag in set(row_tag[1].split(" ")) if nlp(item_praise).similarity(nlp(item_tag)) == 1]
# row 99 is done.
# Total run time for 500 rows is: 552.9995832443237

# %%
df_temp = pd.DataFrame(list_tag, columns=['index_', 'tag'])
df_temp
# Out:
#     index_    tag
# 0       35   TEC5
# 1       88  TEC15
# 2       37   TEC5
# 3       66    NaN
# 4       96   TEC3
# ..     ...    ...
# 95      95  TEC13
# 96      83  TEC17
# 97      26  TEC15
# 98      31   TEC5
# 99      89  TEC13
#
# [100 rows x 2 columns]

# %%
df_sample_100 = pd.merge(df_praise, df_temp, how="left", left_index=True, right_on='index_')

# %%
df_sample_100 = df_sample_100.loc[df_sample_100.index.dropna()]

# %%
df_sample_100.columns
# Out:
# Index(['Category Code', 'To', 'From', 'Reason for dishing', 'Server', 'Date',
#        'Room', 'v1 norm', 'v2 norm', 'v3 norm', 'Avg %', 'IH per Praise',
#        'IH per person', 'index_', 'tag'],
#       dtype='object')

# %%
df_compare = df_sample_100[['Category Code', 'tag', 'Reason for dishing']]

# %%
df_compare.isnull().sum()
# Out:
# Category Code          0
# tag                   30
# Reason for dishing     0
# dtype: int64

# %%
df_compare.head()
# Out:
#      Category Code    tag  \
# 58.0         TEC15  TEC15
# 44.0         TEC12    NaN
# 32.0         TEC12   TEC4
# 36.0         TEC12   TEC1
# 25.0         TEC12  TEC15
#
#                                                                                                                   Reason for dishing
# 58.0                                                                              always caring finicky bot valued community members
# 44.0                                                                           masana temples recommendation nice mix low high beats
# 32.0                                                                                                       joining legal weekly sync
# 36.0                                                                                presence energy smiles comms working group today
# 25.0  mentioning retweeting te commons socials past week thank helping us grow token engineering commons community spreading message

# %%
# list_tag = []
# temp_1 = []
# temp_2 = []
# temp_3 = []
# counter = 0

# start_time = time.time()
# for index_praise in praise_set:
#     for row_tag in tag_dict:
#         temp_set_1 = set(index_praise[1].split(" "))
#         for item_praise in temp_set_1:
#             temp_set_2 = set(row_tag[1].split(" "))
#             for item_tag in temp_set_2:
#                 tag_token = nlp(item_tag)
#                 reason_token = nlp(item_praise)
#                 if reason_token.similarity(tag_token) == 1:
#                     temp_1.append(row_tag[0])
#             if len(temp_1)>=1:
#                 temp_2.append(check_freq(temp_1))
#                 temp_1 = []
#         if len(temp_2)>=1:
#             temp_3.append(check_freq(temp_2))
#             temp_2 = []
#     if len(temp_3)>=1:
#         list_tag.append((index_praise[0], check_freq(temp_3)))
#         temp_3 = []
#     else:
#         list_tag.append((index_praise[0],np.nan))
#     print(f"row {counter} is done.", end='\r')
#     counter+=1

# end_time = time.time()
# print(f"\nTotal run time for {df_praise.shape[0]} rows is: {end_time - start_time}")

# %%
# for i in range(1, 101):
#     print('#'*i+' '*(101-i)+f'{i}%', end='\r')
#     time.sleep(0.1)
